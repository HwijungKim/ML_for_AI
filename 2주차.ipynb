# %% [markdown]
# <a href="https://colab.research.google.com/github/HwijungKim/ML_for_AI/blob/main/%082%EC%A3%BC%EC%B0%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# %%
team_df = pd.DataFrame(
    {
        'Name': ['윤효정', '김가은', '좌대형', '조다영', '김휘중'],
        'Nationality': ['한국','한국','한국','한국','한국'],
        'Hobby' : ['축구하기', '음악감상', '운동', '영화', '축구시청']

    }
)

team_df
# Out:
#   Name Nationality Hobby
# 0  윤효정          한국  축구하기
# 1  김가은          한국  음악감상
# 2  좌대형          한국    운동
# 3  조다영          한국    영화
# 4  김휘중          한국  축구시청

# %%
team_df['학과'] =['응용통계', '응용통계','응용통계', '응용통계', '경영']

# %%
team_df.set_index('Name', inplace=True)

# %%
team_df
# Out:
#      Nationality Hobby    학과
# Name
# 윤효정           한국  축구하기  응용통계
# 김가은           한국  음악감상  응용통계
# 좌대형           한국    운동  응용통계
# 조다영           한국    영화  응용통계
# 김휘중           한국  축구시청    경영

# %%
team_df.to_csv('team_df.csv')

# %%
df_1 = pd.read_csv('team_df.csv',index_col=0)
df_1
# Out:
#      Nationality Hobby    학과
# Name
# 윤효정           한국  축구하기  응용통계
# 김가은           한국  음악감상  응용통계
# 좌대형           한국    운동  응용통계
# 조다영           한국    영화  응용통계
# 김휘중           한국  축구시청    경영
